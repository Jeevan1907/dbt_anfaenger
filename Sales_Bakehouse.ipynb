-- %%
create catalog if not exists bakehouse;
use catalog bakehouse;

-- %%
create table bakehouse.default.bronze_customers as select *, current_timestamp() as ingest_ts, case customerID is null or first_name is null or last_name is null then 0 else 1 end as is_corrupt  from samples.bakehouse.sales_customers;
